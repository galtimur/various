# %%
from parse_docx import parse_docx_to_json, process_docx_files
import os
from pathlib import Path
import json

# %%
process_docx_files("downloads")
# Out:
# Processing DOCX files: 100%|██████████| 6395/6395 [02:45<00:00, 38.60it/s]

# %%
records = []
with open("all_data.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        if line.strip():  # skip blank lines
            records.append(json.loads(line))
